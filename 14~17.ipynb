# %% [markdown]
# 여태까지 한거
# print 변수할당등등
# 수학식 평균, 분산과 표준편차
# 분산은 제곱의 합의 평균-평균의 제곱
# 표준화 등등
# 표준화는 평균 0, 분산은 1로

# %% [markdown]
# 벡터의 연산

# %% [markdown]
# 정보를 모으기
# 차원에 해당하는 값은 바뀌면 안된다.

# %%
#벡터끼리 더하기
#벡터의 차원끼리 더하고 빼고 곱하기
#벡터는 값들의 array이다.

# %% [markdown]
# v=(x1,x2,x3)
# u=(y1,y2,y3)

# %% [markdown]
# 변수에 할당

# %%
x1,y1,z1=1,2,3
x2,y2,z2=3,4,5

# %%
x3=x1+x2
y3=y1+y2
z3=z1+z2

# %%
print(x3,y3,z3,sep=",")
# Out:
# 4,6,8

# %%
x4=x1-x2
y4=y1-y2
z4=z1-z2

# %%
print(x4,y4,z4,sep=",")
# Out:
# -2,-2,-2

# %%
#하다마르
x5=x1*x2
y5=y1*y2
z5=z1*z2

# %%
print(x5,y5,z5,sep=",")
# Out:
# 3,8,15

# %%
x3=x1+x2
y3=y1+y2
z3=z1+z2
print(x3,y3,z3,sep=",")
# Out:
# 4,6,8

# %%
x4=x1-x2
y4=y1-y2
z4=z1-z2
print(x4,x4,z4,sep=",")
# Out:
# -2,-2,-2

# %%
x5=x1*y2
y5=y1*y2
z5=z1*z5
print(x5,y5,z5,sep=",")
# Out:
# 4,8,45

# %% [markdown]
# 1-15 스칼라와 벡터의 계산

# %% [markdown]
# 2*v=2*x1,2*y1,2*z1

# %%
x1,y1,z1=1,2,3
x2,y2,z2=x1*2,y1*2,z1*2
print(x2,y2,z2)
# Out:
# 2 4 6

# %%
x3,y3,z3=2-x1,2-y1,2-z1
print(x3,y3,z3)
# Out:
# 1 0 -1

# %%
x4,y4,z4=2+x1,2+x2,2+x3
print(x4,y4,z4)
# Out:
# 3 4 3

# %% [markdown]
# norm은 벡터의 크기이다.
# 제곱의 합한 다음 루트를 하기

# %%
x,y,z=1,2,3
norm=(x**2+y**2+z**2)**0.5
print(norm)
norm=(x**2+y**2+z**2)**0.5
# Out:
# 3.7416573867739413

# %% [markdown]
# 1-17 Unit Vector 크기가 1인 벡터, 스칼라와 벡터의 곱 이용
# 각 원소/norm을 이용

# %%
x,y=3,4
norm=(x**2+y**2)**0.5
x1=x/norm
y1=y/norm
print(x1,y1)
print("크기 합은 1:",(x1**2+y1**2)**0.5)
# Out:
# 0.6 0.8
# 크기 합은 1: 1.0

# %%
x,y,z=1,2,3
norm=(x**2+y**2+z**2)**0.5
x,y,z=x/norm,y/norm,z/norm
print((x**2+y**2+z**2)**0.5)
# Out:
# 1.0
